# %% [markdown]
# ### 1. What are escape characters, and how do you use them?
# Answer : - Escape characters represent characters in string values that can be be difficult or impossible to type into code.

# %% [markdown]
# ### 2. What do the escape characters n and t stand for?
# Answer : - \n for new line and \t stands for tab

# %% [markdown]
# ### 3. What is the way to include backslash characters in a string?
# Answer : - "\\" escape character can represent a backslash character in a string.

# %% [markdown]
# ### 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?
# Answer : - Because single quote character is inside double quote. If we need single inside single quote, we need to use "\\"

# %%
'Howl\'s Moving Castle'
# Out:
# "Howl's Moving Castle"

# %% [markdown]
# ### 5. How do you write a string of newlines if you don't want to use the n character?
# Answer : - By using Multiline strings. e.g., "'''#multiline text'''"

# %% [markdown]
# ### 6. What are the values of the given expressions?
#
# 'Hello, world!'[1]
#
# 'Hello, world!'[0:5]
#
# 'Hello, world!'[:5]
#
# 'Hello, world!'[3:]
#
# Answer : -
#
# 'Hello, world!'[1] --> 'e'
#
# 'Hello, world!'[0:5] --> 'Hello'
#
# 'Hello, world!'[:5] --> 'Hello'
#
# 'Hello, world!'[3:] --> 'lo, world!'

# %%
'Hello, world!'[1]
# Out:
# 'e'

# %%
'Hello, world!'[0:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %%
7. What are the values of the following expressions?

'Hello'.upper() --> 'HELLO'
'Hello'.upper().isupper() --> True
'Hello'.upper().lower() --> 'hello'

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# ### 8. What are the values of the following expressions?
#
# 'Remember, remember, the fifth of July.'.split() --> ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
# '-'.join('There can only one.'.split()) --> 'There-can-only-one.'

# %%
'Remember, remember, the fifth of July.'.split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# ### 9. What are the methods for right-justifying, left-justifying, and centering a string?
# Answer : - rjust() for right-justifying, ljust() for left-justifying, and center() for centering a string are the methods.

# %% [markdown]
# ### 10. What is the best way to remove whitespace characters from the start or end?
# Answer : - strip() --> from both start and end, lstrip() for left/start and rstrip() for right/end.
