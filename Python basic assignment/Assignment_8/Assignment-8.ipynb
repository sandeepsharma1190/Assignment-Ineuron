# %% [markdown]
# ### 1. Is the Python Standard Library included with PyInputPlus?
#
# Answer: - No we have to install this libarary by using syntax "!pip install PyInputPlus". Once done with the same. we can start importing and using thhis library.

# %% [markdown]
# ### 2. Why is PyInputPlus often imported as pyip with import pyinputplus?
#
# Answer : - pyip will work as a short name. We generally do it because we can save out time and complexity by using short name. We dont have to use "pyinputplus" everytime.

# %% [markdown]
# ### 3. How do you distinguish between inputInt() and inputFloat()?
#
# Answer : - inputInt() always takes an integer as an input and inputFloat() always takes a float value as an input.

# %% [markdown]
# ### 4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?
#
# Answer : - By Calling "pyip.inputint(min=0, max=99)".

# %% [markdown]
# ### 5. What is transferred to the keyword arguments allowRegexes and blockRegexes?
#
# Answer : - The allowRegexes and blockRegexes keyword arguments take a list of regular expression strings to check what the our function will accept or reject as an input.

# %% [markdown]
# ### 6. If a blank input is entered three times, what does inputStr(limit=3) do?
#
# Answer: - By default, blank input isn’t allowed unless the blank keyword argument is set to True. Once we wil mark it true, we will get "RetryLimitException" or "TimeoutException" error.

# %% [markdown]
# ### 7. If blank input is entered three times, what does inputStr(limit=3, default='hello') do?
#
# Answer : -  When we pass a default keyword argument, the function returns the default value instead of raising an exception. The function will returns the value 'hello'.
