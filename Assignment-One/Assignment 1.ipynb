# %% [markdown]
# # First Assignment Python Basic

# %% [markdown]
# ### 1. What are the differences between operators and values in the following?
#
# Answer: -
# operators = *, -, /, +
# values = 'hello', -87.8, 6
# * = Operator, can be used for multiplication
# 'hello' = it’s a string, which can be assigned as value to a variable.
# -87.8 = Float number, it is a value
# - = Operator for subtraction
# / = Operator for Division
# + = Operator for Addition
# 6 = Integer value

# %% [markdown]
# ### 2. What is the difference between string and variable?
# Answer : -
# Spam = Variable
# 'spam' = String
# Spam = ‘spam’, variable basically holds a value, which can be called whenever required. String is the value, which can be assigned to any variable. Whenever we need to call a particular string, we need to call a variable.

# %% [markdown]
# ### 3. Describe three different data forms.
# Answer : - Integer = Hold only a whole number. Numbers, which are without any decimal value.
# Float = Called as master number, holds values with decimal numbers.
# String = Basically inside quote everything is a string, It can be numbers, text or both. It won’t function any mathematical expression. It will take every value as string.

# %% [markdown]
# ### 4. What makes up an expression? What are the functions of all expressions?
# Answer : - An expression is a combination of multiple operators, variables, values and constant for an output. All expressions can be used to calculate a variable.

# %% [markdown]
# ### 5. In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?
# Answer : - An expression is a combination of multiple operators, variables, values and constant for an output. All expressions can be used to calculate a variable.
# Declaration means, declaring a value for a variable or declaring a function or declaring a class etc.
# Declaration can be a part of an expression for a further calculation.
#
#
# Note: - # Avoiding “In this chapter, assignment statements such as spam = 10 were added”, as discussed with Ineuron support. Unable to understand this statement/Question.

# %% [markdown]
# ### 6. After running the following code, what does the variable bacon contain?
# Answer : -
#
# bacon = 22
# bacon + 1
# Bacon value remained as 22, because we are not saving the value back to bacon. But after running this code, value for bacon+1 = 23.

# %% [markdown]
# ### 7. What should the values of the following two terms be?
# Answer: -
# 'spam' + 'spamspam' = Output in Python will be 'spamspamspam'
#
# 'spam' * 3 = Output in Python will be 'spamspamspam'

# %% [markdown]
# ### 8. Why is it that eggs is a true variable name but 100 is not?
# Answer : - Because, we can’t start any variable number with a number. Variable names in python should be start with alphabets.

# %% [markdown]
# ### 9. Which of the following three functions may be used to convert a value to an integer, a floating-point number, or a string?
# Answer : - For integer = int()
# For floating-point number = flaot()
# For string = str()

# %% [markdown]
# ### 10. What is the error caused by this expression? What would you do about it?
# Answer : -
# 'I have eaten ' + 99 + ' burritos.'
# We will get typeerror here, because 99 is not a string. We must convert 99 to a string. There are two ways we can follow.
# 'I have eaten ' + ‘99’ + ' burritos.'
# 'I have eaten ' + str (99) + ' burritos.'
