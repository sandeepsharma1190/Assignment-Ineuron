# %% [markdown]
# ### 1. What exactly is []?
# Answer : - It’s a sign for an empty List.

# %% [markdown]
# ### 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)¶
# Answer : - By using insert statement and spam[2] = 'hello' statement

# %%
spam = [2, 4, 6, 8, 10] 
spam.insert(2, 'hello')
spam
# Out:
# [2, 4, 'hello', 6, 8, 10]

# %%
spam = [2, 4, 6, 8, 10] 
spam[2] = 'hello'
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ## Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %% [markdown]
# ### 3. What is the value of spam[int(int('3' * 2) / 11)]?
# Answer : - It will calculate the index and give us value 'd'

# %%
spam = ['a', 'b', 'c', 'd'] 
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %% [markdown]
# ### 4. What is the value of spam[-1]?
# Answer : - It will pick value from "-1" index, which is the last index

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# ### 5. What is the value of spam[:2]?
# Answer : - It will give output for 0 and 1 index and will leave 2 index as an upperbound value

# %%
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# ## Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
bacon = [3.14, 'cat', 11, 'cat', True]

# %% [markdown]
# ### 6. What is the value of bacon.index('cat')?
# Answer : - It will index for first "cat" value, which is on 1 or -4 index

# %%
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# ### 7. How does bacon.append(99) change the look of the list value in bacon?
# Answer : - It will add value 99 in the end of the list

# %%
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ### 8. How does bacon.remove('cat') change the look of the list meaning in bacon?
# Answer : - It will remove first "cat value from list"

# %%
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# ### 9. What are the list concatenation and list replication operators?
# Answer : - list concatenation operator is "+" and replication operators is "*"

# %% [markdown]
# ### 10. What is difference between the list methods append() and insert()?
# Answer : -
# Append: - mean adding value in the end, we dont give index to store a value, -1 is the index by default.
#
# Insert : - Means, we can add value anywhere in the list by giving index number

# %% [markdown]
# ### 11. What are the two methods for removing items from a list?
# Answer : - pop, del and remove are the three functions, which can be used to remove items from a list

# %% [markdown]
# ### 12. Describe how list values and string values are identical.
# Answer : - both list and string values are iterable values. both have index and we can perform slicing and text manipulation. length can be calculated for both. in and not in can work on both

# %% [markdown]
# ### 13. What's the difference between tuples and lists?
# Answer: -
#
# Tuples are immutable and fast. We cant edit any tuple. created by using parentheses () or tuple function.
#
# Lists are mutable, hence bit slow than tuples. We can add/ remove as many values as we can. created by using square brackets [] or list function.

# %% [markdown]
# ### 14. How do you type a tuple value that only contains the integer 42?
# Answer : - Using comma after value 42

# %%
a = 42,
aa = (42,)
type(a)
type(aa)
# Out:
# tuple

# %% [markdown]
# ### 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %%
list1 = [1,2,3]

# %%
tup = tuple(list1)
tup
# Out:
# (1, 2, 3)

# %%
list2 = list(tup)
list2
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
# Answer : - References to the values in list

# %% [markdown]
# ### 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# ### Question 17 changed to difference between shallow copy and deep copy as suggested by ineuron skype support

# %% [markdown]
# Answer : - Shallow copy means, creating a copy of a variable. However, when we will make changes in child variable, it will make changes in master variable as well
# Deep copy : - Creating a deep copy of a variable, where changes made in child or mother variable wont impact each other.
