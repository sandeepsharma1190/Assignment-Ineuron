# %% [markdown]
# ### 1. What are the benefits of including roles in the programmes?
# Answer : - Often multiple roles are associated with each job, depending on the needs and phase within the program. Like we can use function to avoid usage of duplicate code. It makes use program, short, crisp and readable.

# %% [markdown]
# ### 2. When does the code in a function run: when it's specified or when it's called?
# Answer : - The code in a function executes after calling a function.

# %% [markdown]
# ### 3. What statement causes a feature to be created?
# Answer : - We use def function to define a feature.
# e.g., "def function_name():""

# %% [markdown]
# ### 4. What is the distinction between a function and a call to a function?
# Answer : - A function consists of the def statement and the code. A function can be created a repeating code, which can be re-used every time.
# Call to a function means, calling a function, which will return a value by using its parameters.

# %% [markdown]
# ### 5. In a Python application, how many global scopes are there? How many local scopes are there?
# Answer : - There is one global scope, and a local scope is created for a function.

# %% [markdown]
# ### 6. When a function call returns, what happens to variables in the local scope?
# Answer : - Variables in local scope become undefined/ destroyed after function call returns.

# %% [markdown]
# ### 7. What is the concept of a return value? Is it possible to have a return value in an expression?
# Answer : - We can use return value as an expression in python. Return value gives us the value after running a function evaluation.

# %% [markdown]
# ### 8. What is the return value of a call to a function that does not have a return statement?
# Answer : - We get None as a return value if it is not identified in a function.

# %% [markdown]
# ### 9. How do you make a function variable refer to the global variable?
# Answer : - By using global statement for a variable inside a function.

# %% [markdown]
# ### 10. What data form does None belong to?
# Answer : - NoneType is the type for None in python.

# %% [markdown]
# ### 11. What does the sentence import areallyourpetsnamederic do?
# Answer : - import areallyourpetsnamederic – it will import “areallyourpetsnamederic” library. Which can be used for further programming.

# %% [markdown]
# ### 12. If you had a bacon() feature in a spam module, how would you call it after importing spam?
# Answer : - spam.bacon()

# %% [markdown]
# ### 13. What can you do to save a programme from crashing if it encounters an error?
# Answer : - By using try clause from error handling techniques.

# %% [markdown]
# ### 14. What is the purpose of the try clause? What is the purpose of the except clause?
# Answer : - Error prone code will be written inside try clause. If it will through an error, it will come under except clause.
