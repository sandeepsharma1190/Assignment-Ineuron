# %% [markdown]
# ### 1.	Write a Python Program to Display Fibonacci Sequence Using Recursion?

# %%
def rec_fib(n):
    if n <= 1:
        return n
    else:
        return (rec_fib(n-1) + rec_fib(n-2))
    
num = int(input('Enter a number: '))

if num <= 0:
    print ('Enter a valid/positive number!!')
else:
    for i in range(num):
        print (rec_fib(i))
# Out:
# Enter a number: 5
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# ### 2.	Write a Python Program to Find Factorial of Number Using Recursion?

# %%
def rec_fac(n):
    if n == 1:
        return n
    else:
        return n*rec_fac(n-1)
        
num = int(input('Enter a number: '))

if num < 0:
    print ('Enter a valid/positive number!!')
elif num == 0:
    print ('Factorial for 0 is 1')
else:
    print ('Factorial for', num, 'is', rec_fac(num))
# Out:
# Enter a number: 5
# Factorial for 5 is 120

# %% [markdown]
# ### 3.	Write a Python Program to calculate your Body Mass Index?

# %%
height = float(input("Input your height in Feet: "))
weight = float(input("Input your weight in Kilogram: "))
print("Your body mass index is: ", round(weight / (height * height), 2))
# Out:
# Input your height in Feet: 5.9
# Input your weight in Kilogram: 90
# Your body mass index is:  2.59

# %% [markdown]
# ### 4.	Write a Python Program to calculate the natural logarithm of any number?

# %%
import math

num1 = int(input('Enter a number to check it\'s log: '))

print (math.log(num1))
# Out:
# Enter a number to check it's log: 4
# 1.3862943611198906

# %% [markdown]
# ### 5.	Write a Python Program for cube sum of first n natural numbers?

# %%
def sum_num(n):
    sum1 = 0
    for i in range(1,n+1):
        sum1 += i**3
    return sum1

num = int(input('Enter any number: '))
print (sum_num(num))
# Out:
# Enter any number: 6
# 441
