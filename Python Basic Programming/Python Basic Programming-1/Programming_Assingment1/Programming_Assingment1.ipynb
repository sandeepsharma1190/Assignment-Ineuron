# %% [markdown]
# ### 1.	Write a Python program to print "Hello Python"?

# %%
a = 'Hello Python'
print (a)
# Out:
# Hello Python

# %%
'Hello Python'
# Out:
# 'Hello Python'

# %% [markdown]
# ### 2.	Write a Python program to do arithmetical operations addition and division.?

# %%
a = 10
b = 5
division = a/b
addition = a+b
print ('Division for', a, 'and', b, 'is: ', division)
print ('Addition for', a, 'and', b, 'is: ', addition)
# Out:
# Division for 10 and 5 is:  2.0
# Addition for 10 and 5 is:  15

# %% [markdown]
# ### 3.	Write a Python program to find the area of a triangle?

# %%
a,b,c = 10,12,14
sum1 = (a+b+c)/2
area = (sum1*(sum1-a)*(sum1-b)* (sum1-c))**0.5
print (area)
# Out:
# 58.787753826796276

# %% [markdown]
# ### 4.	Write a Python program to swap two variables?

# %%
a,b = 5,10
print ('Value of a is:', a)
print ('Value of b is:', b)
print ('-----------------------')
b,a = a,b
print ('Updated value of a is:', a)
print ('Updated value of b is:', b)
# Out:
# Value of a is: 5
# Value of b is: 10
# -----------------------
# Updated value of a is: 10
# Updated value of b is: 5

# %% [markdown]
# ### 5.	Write a Python program to generate a random number?

# %%
import random
random.randint(1,100)
# Out:
# 59
